# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

# Regex pattern for parsing log entries
log_pattern = re.compile(
    r'(?P<ip>\d+\.\d+\.\d+\.\d+)\s+-\s+(?P<country>[A-Z]+)\s+-\s+\[(?P<timestamp>[^\]]+)\]\s+'
    r'"(?P<method>GET|POST|PUT|DELETE|PATCH|OPTIONS|HEAD)\s+(?P<path>[^"]+)\s+HTTP/[^"]+"\s+'
    r'(?P<status>\d+)\s+\d+\s+"[^"]*"\s+"(?P<user_agent>[^"]+)"\s+(?P<response_time>\d+)'
)

def parse_log_file(file_path):
    records = []

    with open(file_path, 'r') as f:
        for line in f:
            match = log_pattern.search(line)
            if match:
                records.append(match.groupdict())

    # Convert to DataFrame
    df = pd.DataFrame(records)

    df['status'] = df['status'].astype(int)
    df['response_time'] = df['response_time'].astype(int)
    df['timestamp'] = pd.to_datetime(df['timestamp'], format='%d/%m/%Y:%H:%M:%S')

    return df

file_path = "sample-log.log"
df = parse_log_file(file_path)
print(df.head())
# Out:
#                ip country           timestamp method  \
# 0   100.34.17.233      NO 2025-07-01 06:00:02    GET
# 1   173.80.18.254      NO 2025-07-01 06:00:04   POST
# 2       10.3.0.48      SE 2025-07-01 06:00:06    GET
# 3   172.56.143.33      US 2025-07-01 06:00:08    GET
# 4  208.54.157.184      NO 2025-07-01 06:00:09   POST
#
#                             path  status  \
# 0  /news/grammy-nominations-2024     302
# 1                              /     200
# 2      /podcasts/behind-the-beat     200
# 3              /terms-of-service     200
# 4                /privacy-policy     200
#
#                                           user_agent  response_time
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...            269
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...            124
# 2  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...            284
# 3  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...            262
# 4  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...            118

# %%
def general_log_analysis(df, start_time=None, end_time=None, keyword=None):
    """
    Analyze web server logs and return comprehensive statistics.
    
    Parameters:
    df (pandas.DataFrame): Log data with columns [timestamp, ip, path, status, response_time, size, user_agent]
    start_time (str): Start time for filtering (optional)
    end_time (str): End time for filtering (optional)
    keyword (str): Keyword to filter paths (optional)
    
    Returns:
    dict: Dictionary containing analysis results
    """
    # Create a copy to avoid modifying original dataframe
    df = df.copy()
    
    # Ensure timestamp is datetime
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    
    # Time filtering
    if start_time and end_time:
        start_time = pd.to_datetime(start_time)
        end_time = pd.to_datetime(end_time)
        df = df[(df['timestamp'] >= start_time) & (df['timestamp'] <= end_time)]

    # Keyword filtering
    if keyword:
        df = df[df['path'].str.contains(keyword, case=False, na=False)]

    summary = {}

    # Basic metrics
    summary['Total Requests'] = len(df)
    summary['Unique IPs'] = df['ip'].nunique()
    
    # Error rate
    summary['Error Rate (%)'] = (
        len(df[df['status'].astype(str).str.startswith(('4', '5'))]) / len(df) * 100
    ) if len(df) > 0 else 0
    
    # Top IPs
    summary['Top IPs'] = df['ip'].value_counts().head(5).to_dict()
    
    # Top Endpoints
    summary['Top Endpoints'] = df['path'].value_counts().head(5).to_dict()
    
    # Status code distribution
    summary['Status Codes'] = df['status'].value_counts().to_dict()
    
    # Requests over time (daily)
    requests_daily = df['timestamp'].dt.floor('D').value_counts().sort_index()
    summary['Requests Over Time (Daily)'] = requests_daily.to_dict()
    
    # Peak hours
    peak_hours = df['timestamp'].dt.hour.value_counts().sort_index()
    summary['Peak Hours'] = peak_hours.head(5).to_dict()
    
    # User agent analysis (if available)
    if 'user_agent' in df.columns:
        summary['Top User Agents'] = df['user_agent'].value_counts().head(5).to_dict()
    
    # Bandwidth usage (if size column exists)
    if 'size' in df.columns:
        summary['Total Bandwidth (MB)'] = round(df['size'].sum() / (1024 * 1024), 2)
    
    # Slowest endpoints (if response_time exists)
    if 'response_time' in df.columns:
        slowest = (
            df.groupby('path')['response_time']
            .mean()
            .sort_values(ascending=False)
            .head(5)
            .round(2)
            .to_dict()
        )
        summary['Slowest Endpoints (avg ms)'] = slowest

    return summary

def pretty_print_analysis(summary, timezone='UTC'):
    """
    Pretty print the log analysis results in a formatted manner.
    
    Parameters:
    summary (dict): Analysis results from general_log_analysis
    timezone (str): Timezone for displaying timestamps
    """
    def print_section(title):
        print(f"\n{'=' * 50}\n{title}\n{'=' * 50}")
    
    def format_timestamp(ts):
        return pd.Timestamp(ts).tz_localize('UTC').tz_convert(timezone).strftime('%Y-%m-%d %H:%M:%S %Z')
    
    print_section("Log Analysis Summary")
    
    # Basic Metrics
    print(f"Total Requests: {summary['Total Requests']:,}")
    print(f"Unique IPs: {summary['Unique IPs']:,}")
    print(f"Error Rate: {summary['Error Rate (%)']:.2f}%")
    
    # Top IPs
    print_section("Top 5 Source IPs")
    for ip, count in summary['Top IPs'].items():
        print(f"{ip}: {count:,} requests")
    
    # Top Endpoints
    print_section("Top 5 Endpoints")
    for path, count in summary['Top Endpoints'].items():
        print(f"{path}: {count:,} requests")
    
    # Status Codes
    print_section("Status Code Distribution")
    for status, count in summary['Status Codes'].items():
        print(f"Status {status}: {count:,} requests")
    
    # Requests Over Time
    print_section("Requests Over Time (Daily)")
    for date, count in summary['Requests Over Time (Daily)'].items():
        formatted_date = format_timestamp(date)
        print(f"{formatted_date.split()[0]}: {count:,} requests")
    
    # Peak Hours
    print_section("Peak Hours")
    for hour, count in summary['Peak Hours'].items():
        print(f"Hour {hour:02d}:00: {count:,} requests")
    
    # User Agents
    if 'Top User Agents' in summary:
        print_section("Top 5 User Agents")
        for ua, count in summary['Top User Agents'].items():
            print(f"{ua[:50]}...: {count:,} requests")
    
    # Bandwidth
    if 'Total Bandwidth (MB)' in summary:
        print_section("Bandwidth Usage")
        print(f"Total: {summary['Total Bandwidth (MB)']:.2f} MB")
    
    # Slowest Endpoints
    if 'Slowest Endpoints (avg ms)' in summary:
        print_section("Slowest Endpoints (Average Response Time)")
        for path, time in summary['Slowest Endpoints (avg ms)'].items():
            print(f"{path}: {time:.2f} ms")

# %%
pretty_print_analysis(general_log_analysis(df))
# Out:
# ==================================================
# Log Analysis Summary
# ==================================================
# Total Requests: 432,096
# Unique IPs: 40,887
# Error Rate: 12.72%
#
# ==================================================
# Top 5 Source IPs
# ==================================================
# 45.133.1.2: 5,400 requests
# 45.133.1.1: 5,400 requests
# 35.185.0.156: 3,600 requests
# 194.168.1.2: 1,859 requests
# 194.168.1.6: 1,855 requests
#
# ==================================================
# Top 5 Endpoints
# ==================================================
# /episodes/ep-42-synthesizer-history: 15,876 requests
# /contact: 15,839 requests
# /about: 15,729 requests
# /artists/emerging-indie-artists: 15,685 requests
# /podcasts/music-producer-interviews: 15,685 requests
#
# ==================================================
# Status Code Distribution
# ==================================================
# Status 200: 354,706 requests
# Status 404: 38,061 requests
# Status 301: 11,169 requests
# Status 302: 7,511 requests
# Status 401: 5,338 requests
# Status 500: 5,233 requests
# Status 304: 3,765 requests
# Status 429: 1,821 requests
# Status 504: 1,459 requests
# Status 503: 1,430 requests
# Status 403: 1,176 requests
# Status 423: 427 requests
#
# ==================================================
# Requests Over Time (Daily)
# ==================================================
# 2025-07-01: 99,202 requests
# 2025-07-02: 113,264 requests
# 2025-07-03: 113,351 requests
# 2025-07-04: 106,279 requests
#
# ==================================================
# Peak Hours
# ==================================================
# Hour 05:00: 3,600 requests
# Hour 06:00: 7,216 requests
# Hour 07:00: 7,256 requests
# Hour 08:00: 21,589 requests
# Hour 09:00: 21,567 requests
#
# ==================================================
# Top 5 User Agents
# ==================================================
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWeb...: 44,882 requests
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7) Ap...: 42,954 requests
# Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like Mac...: 41,481 requests
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWeb...: 41,233 requests
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7) Ap...: 41,137 requests
#
# ==================================================
# Slowest Endpoints (Average Response Time)
# ==================================================
# /search?duration=medium&duration=short&s=Cliffords: 500.00 ms
# /search?duration=medium&duration=short&s=CMAT: 500.00 ms
# /search?genre=metalcore&s=Phoebe+Bridgers&s=Wet+Leg&s=Cliffords: 500.00 ms
# /search?duration=long&year=2022&sort=date: 500.00 ms
# /search?genre=indie+rock&genre=hip+hop&sort=date&year=2020: 500.00 ms

# %%
# numbers are great but data visualisation is better

# create a heat map of day and hour to see taffic
df['day_of_week'] = df['timestamp'].dt.day_name()
df['hour'] = df['timestamp'].dt.hour

# Create a pivot table
heatmap_data = df.groupby(['day_of_week', 'hour']).size().unstack().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
)

# Plot heatmap
plt.figure(figsize=(14, 6))
sns.heatmap(heatmap_data, cmap='viridis')
plt.title('Request Frequency by Day and Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Day of Week')
plt.tight_layout()
plt.show()

# %%
# line graph to show requests over time

requests_over_time = df['timestamp'].dt.floor('D').value_counts().sort_index()

# Plot
plt.figure(figsize=(12, 6))
requests_over_time.plot()
plt.title('Requests Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Requests')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
country_count = error_logs['country'].value_counts()

plot = country_count.plot.pie(y='country', figsize=(5, 5))

# %%
russian_bot = df[df['ip'] == '45.133.1.1']
print(russian_bot)
print(russian_bot['user_agent'].value_counts())
# Out:
#                 ip country           timestamp   method  \
# 151435  45.133.1.1      RU 2025-07-02 15:00:00  OPTIONS
# 151436  45.133.1.1      RU 2025-07-02 15:00:00  OPTIONS
# 151437  45.133.1.1      RU 2025-07-02 15:00:00  OPTIONS
# 151448  45.133.1.1      RU 2025-07-02 15:00:02      PUT
# 151449  45.133.1.1      RU 2025-07-02 15:00:02      GET
# ...            ...     ...                 ...      ...
# 174782  45.133.1.1      RU 2025-07-02 15:59:56     POST
# 174783  45.133.1.1      RU 2025-07-02 15:59:56     HEAD
# 174795  45.133.1.1      RU 2025-07-02 15:59:58    PATCH
# 174796  45.133.1.1      RU 2025-07-02 15:59:58      PUT
# 174797  45.133.1.1      RU 2025-07-02 15:59:58      GET
#
#                                path  status  \
# 151435                /api/v1/users     200
# 151436            /api/v2/users/../     404
# 151437         /api/v3/users/../../     404
# 151448    /api/v2/users/profile/dev     404
# 151449  /api/v3/users/profile/debug     404
# ...                             ...     ...
# 174782            /api/version/test     200
# 174783       /api/subscriptions/dev     200
# 174795         /api/internal/logs/1     200
# 174796                /api/backup/0     200
# 174797             /api/database/-1     404
#
#                                              user_agent  response_time  \
# 151435                                      nikto/2.1.6            166
# 151436                                     HTTPie/3.2.0            154
# 151437                          Burp Suite Professional            205
# 151448                                        OWASP ZAP            221
# 151449                                      nikto/2.1.6            151
# ...                                                 ...            ...
# 174782                                        OWASP ZAP            197
# 174783  Mozilla/5.0 (compatible; Nmap Scripting Engine)             91
# 174795                           python-requests/2.28.1             92
# 174796                                    sqlmap/1.6.12             53
# 174797                          Burp Suite Professional            119
#
#        day_of_week  hour
# 151435   Wednesday    15
# 151436   Wednesday    15
# 151437   Wednesday    15
# 151448   Wednesday    15
# 151449   Wednesday    15
# ...            ...   ...
# 174782   Wednesday    15
# 174783   Wednesday    15
# 174795   Wednesday    15
# 174796   Wednesday    15
# 174797   Wednesday    15
#
# [5400 rows x 10 columns]
# user_agent
# Postman/1.0                                        637
# curl/7.68.0                                        627
# OWASP ZAP                                          617
# Burp Suite Professional                            606
# sqlmap/1.6.12                                      604
# Mozilla/5.0 (compatible; Nmap Scripting Engine)    593
# HTTPie/3.2.0                                       582
# python-requests/2.28.1                             571
# nikto/2.1.6                                        563
# Name: count, dtype: int64

# %%
bot_keywords = [
    'bot', 'spider', 'crawler', 'curl', 'wget', 'scrapy', 'httpclient',
    'python', 'ruby', 'java', 'go-http', 'aiohttp', 'libwww', 'node-fetch',
    'phantomjs', 'selenium', 'headless', 'slurp', 'feedfetcher', 'http-request',
    'scan', 'nutch', 'httpx', 'axios', 'burp suite professional', 'sqlmap', 'nikto', 'postman'
]

pattern = '|'.join(bot_keywords)
bots = df[df['user_agent'].str.contains(pattern, case=False, na=False)]

# %%
bots['country'].value_counts().plot.pie(y='country', figsize=(5, 5))
# Out:
# <Axes: ylabel='count'>

# %%
prev_logs = 60
df.iloc[int(error_logs.iloc[0][7])-prev_logs:int(error_logs.iloc[0][7])] # looks at the records before the server error (this gets me nowhere)
# Out:
# /tmp/ipykernel_88923/783660280.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[int(error_logs.iloc[0][7])-prev_logs:int(error_logs.iloc[0][7])] # looks at the records before the server error (this gets me nowhere)
#                  ip country           timestamp method  \
# 4    208.54.157.184      NO 2025-07-01 06:00:09   POST
# 5      96.114.162.7      SE 2025-07-01 06:00:15    GET
# 6     107.78.231.35      FR 2025-07-01 06:00:16    GET
# 7      174.54.112.5      DK 2025-07-01 06:00:17    GET
# 8      192.168.3.81      FR 2025-07-01 06:00:19   POST
# 9    99.224.121.154      US 2025-07-01 06:00:22    GET
# 10      172.21.0.92      DE 2025-07-01 06:00:23    GET
# 11    100.34.131.87      DK 2025-07-01 06:00:25    GET
# 12     68.1.252.104      SE 2025-07-01 06:00:27   POST
# 13    174.50.109.73      DK 2025-07-01 06:00:28    GET
# 14      10.12.0.218      CA 2025-07-01 06:00:31    GET
# 15    173.161.93.22      UK 2025-07-01 06:00:34    GET
# 16      172.27.2.45      NO 2025-07-01 06:00:38    GET
# 17    71.233.206.53      CA 2025-07-01 06:00:40    GET
# 18   173.161.195.33      US 2025-07-01 06:00:42    GET
# 19  157.242.241.146      NL 2025-07-01 06:00:43    GET
# 20   151.103.189.99      UK 2025-07-01 06:00:45    GET
# 21     98.114.31.95      FR 2025-07-01 06:00:47    GET
# 22       172.17.3.6      NL 2025-07-01 06:00:49    GET
# 23   192.168.29.233      DE 2025-07-01 06:00:50    GET
# 24   108.163.18.126      NL 2025-07-01 06:00:51    GET
# 25     172.17.2.132      SE 2025-07-01 06:00:53    GET
# 26    174.51.54.122      NL 2025-07-01 06:00:54    GET
# 27   172.57.247.125      AU 2025-07-01 06:00:55    GET
# 28    174.54.191.60      US 2025-07-01 06:00:56    GET
# 29     172.31.3.110      UK 2025-07-01 06:00:57    GET
# 30     91.205.79.61      NO 2025-07-01 06:00:58    GET
# 31      192.168.7.7      UK 2025-07-01 06:00:59    GET
# 32   108.164.118.72      CA 2025-07-01 06:01:00    GET
# 33      172.18.0.29      NO 2025-07-01 06:01:01    GET
# 34    174.49.22.197      NO 2025-07-01 06:01:02    GET
# 35      68.3.23.185      DK 2025-07-01 06:01:03    GET
# 36        81.4.55.5      NL 2025-07-01 06:01:04   POST
# 37    73.223.229.65      NO 2025-07-01 06:01:05    GET
# 38       10.3.0.106      AU 2025-07-01 06:01:06    GET
# 39    99.203.156.62      DE 2025-07-01 06:01:07    GET
# 40      68.2.242.97      DE 2025-07-01 06:01:09    GET
# 41      172.22.3.36      AU 2025-07-01 06:01:16    GET
# 42    91.205.117.72      US 2025-07-01 06:01:17    GET
# 43   100.34.238.117      NO 2025-07-01 06:01:19    GET
# 44   76.169.196.162      AU 2025-07-01 06:01:20    GET
# 45    73.222.93.203      DK 2025-07-01 06:01:25    GET
# 46      81.3.15.161      SE 2025-07-01 06:01:30   POST
# 47        10.5.1.69      DK 2025-07-01 06:01:31    GET
# 48   174.49.163.220      UK 2025-07-01 06:01:32    GET
# 49   192.168.19.213      FR 2025-07-01 06:01:34    GET
# 50      172.17.1.39      UK 2025-07-01 06:01:35    GET
# 51   174.50.228.253      NL 2025-07-01 06:01:36    GET
# 52   192.168.22.241      DE 2025-07-01 06:01:37    GET
# 53    76.197.77.101      FR 2025-07-01 06:01:39   POST
# 54      68.3.68.176      DK 2025-07-01 06:01:40    GET
# 55      81.3.83.234      CA 2025-07-01 06:01:41    GET
# 56      99.204.7.47      FR 2025-07-01 06:01:44    PUT
# 57      86.1.30.211      FR 2025-07-01 06:01:45    GET
# 58    99.205.119.74      AU 2025-07-01 06:01:49    GET
# 59   91.206.225.191      CA 2025-07-01 06:01:50    GET
# 60      108.49.4.91      US 2025-07-01 06:01:52    GET
# 61    173.162.88.23      NO 2025-07-01 06:01:55    GET
# 62    100.36.96.158      US 2025-07-01 06:01:56    GET
# 63    73.223.50.113      CA 2025-07-01 06:01:59    GET
#
#                                                  path  status  \
# 4                                     /privacy-policy     200
# 5                                  /images/banner.jpg     200
# 6                                  /subscribe-premium     200
# 7                 /podcasts/music-producer-interviews     200
# 8                                       /api/episodes     404
# 9                                     /privacy-policy     200
# 10                                      /api/episodes     200
# 11                                           /contact     200
# 12      /api/v1/auth/login?username=bob%40company.com     200
# 13              /reviews/album-review-midnight-echoes     200
# 14                                           /contact     200
# 15                                             /about     200
# 16                                      /api/podcasts     404
# 17                /podcasts/music-producer-interviews     200
# 18                                                  /     200
# 19                /episodes/ep-42-synthesizer-history     200
# 20                                       /favicon.ico     200
# 21                /episodes/ep-42-synthesizer-history     200
# 22                     /genres/electronic-music-guide     301
# 23                                           /contact     200
# 24                                    /privacy-policy     200
# 25                /episodes/ep-42-synthesizer-history     200
# 26                    /articles/the-evolution-of-jazz     200
# 27                                  /static/js/app.js     200
# 28                                       /favicon.ico     200
# 29                                                  /     200
# 30                          /podcasts/behind-the-beat     200
# 31                                      /api/episodes     200
# 32                          /podcasts/behind-the-beat     200
# 33                                           /contact     200
# 34                                       /favicon.ico     200
# 35                                  /terms-of-service     200
# 36                                    /privacy-policy     200
# 37                                      /api/episodes     200
# 38                               /static/css/main.css     200
# 39                /podcasts/music-producer-interviews     200
# 40                                      /api/episodes     200
# 41  /search?sort=date&year=2023&genre=alternative+...     200
# 42                                                  /     200
# 43                                      /api/articles     200
# 44                                  /terms-of-service     200
# 45                    /articles/the-evolution-of-jazz     200
# 46                                                  /     200
# 47                    /articles/the-evolution-of-jazz     200
# 48                                             /about     200
# 49                                      /api/episodes     200
# 50                  /articles/indie-rock-revival-2024     200
# 51                                   /images/logo.png     200
# 52                      /news/grammy-nominations-2024     200
# 53          /api/v1/auth/login?username=alice.johnson     200
# 54                                 /subscribe-premium     200
# 55                    /artists/emerging-indie-artists     200
# 56                /episodes/ep-42-synthesizer-history     200
# 57                                                  /     200
# 58                     /genres/electronic-music-guide     200
# 59                    /articles/the-evolution-of-jazz     200
# 60           /interviews/studio-sessions-with-legends     200
# 61                                      /api/articles     200
# 62              /reviews/album-review-midnight-echoes     200
# 63                                 /subscribe-premium     200
#
#                                            user_agent  response_time  \
# 4   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...            118
# 5   Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...            374
# 6   Mozilla/5.0 (Linux; Android 14; SM-G998B) Appl...            262
# 7   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...            164
# 8   Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...            606
# 9   Mozilla/5.0 (Linux; Android 14; SM-G998B) Appl...            248
# 10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...            364
# 11  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...            204
# 12  Mozilla/5.0 (Linux; Android 14; SM-G998B) Appl...            523
# 13  Mozilla/5.0 (iPad; CPU OS 17_2_1 like Mac OS X...            347
# 14  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...            294
# 15  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...            342
# 16  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...            797
# 17  Mozilla/5.0 (Linux; Android 14; SM-G998B) Appl...            126
# 18  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...            299
# 19  Mozilla/5.0 (iPad; CPU OS 17_2_1 like Mac OS X...            266
# 20  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...             99
# 21  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...             98
# 22  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...            128
# 23  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...            253
# 24  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...            353
# 25  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...            263
# 26  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...             58
# 27  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...             98
# 28  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...             53
# 29  Mozilla/5.0 (Android 14; Mobile; rv:121.0) Gec...            176
# 30  Mozilla/5.0 (iPad; CPU OS 17_2_1 like Mac OS X...            337
# 31  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...            161
# 32  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...            155
# 33  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...            154
# 34  Mozilla/5.0 (iPad; CPU OS 17_2_1 like Mac OS X...             50
# 35  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...            227
# 36  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...            264
# 37  Mozilla/5.0 (iPad; CPU OS 17_2_1 like Mac OS X...            204
# 38  Mozilla/5.0 (Android 14; Mobile; rv:121.0) Gec...             44
# 39  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...            391
# 40  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...            486
# 41  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...            166
# 42  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...             57
# 43  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...            237
# 44  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...            131
# 45  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...            260
# 46  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...            219
# 47  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...            222
# 48  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...            254
# 49  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...            461
# 50  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...            367
# 51  Mozilla/5.0 (iPad; CPU OS 17_2_1 like Mac OS X...            279
# 52  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...            240
# 53  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...            437
# 54  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...            240
# 55  Mozilla/5.0 (iPad; CPU OS 17_2_1 like Mac OS X...             58
# 56  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...             93
# 57  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...            261
# 58  Mozilla/5.0 (Linux; Android 14; SM-G998B) Appl...            349
# 59  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             82
# 60  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...            210
# 61  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...            344
# 62  Mozilla/5.0 (iPhone; CPU iPhone OS 17_2_1 like...            335
# 63  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...            238
#
#    day_of_week  hour
# 4      Tuesday     6
# 5      Tuesday     6
# 6      Tuesday     6
# 7      Tuesday     6
# 8      Tuesday     6
# 9      Tuesday     6
# 10     Tuesday     6
# 11     Tuesday     6
# 12     Tuesday     6
# 13     Tuesday     6
# 14     Tuesday     6
# 15     Tuesday     6
# 16     Tuesday     6
# 17     Tuesday     6
# 18     Tuesday     6
# 19     Tuesday     6
# 20     Tuesday     6
# 21     Tuesday     6
# 22     Tuesday     6
# 23     Tuesday     6
# 24     Tuesday     6
# 25     Tuesday     6
# 26     Tuesday     6
# 27     Tuesday     6
# 28     Tuesday     6
# 29     Tuesday     6
# 30     Tuesday     6
# 31     Tuesday     6
# 32     Tuesday     6
# 33     Tuesday     6
# 34     Tuesday     6
# 35     Tuesday     6
# 36     Tuesday     6
# 37     Tuesday     6
# 38     Tuesday     6
# 39     Tuesday     6
# 40     Tuesday     6
# 41     Tuesday     6
# 42     Tuesday     6
# 43     Tuesday     6
# 44     Tuesday     6
# 45     Tuesday     6
# 46     Tuesday     6
# 47     Tuesday     6
# 48     Tuesday     6
# 49     Tuesday     6
# 50     Tuesday     6
# 51     Tuesday     6
# 52     Tuesday     6
# 53     Tuesday     6
# 54     Tuesday     6
# 55     Tuesday     6
# 56     Tuesday     6
# 57     Tuesday     6
# 58     Tuesday     6
# 59     Tuesday     6
# 60     Tuesday     6
# 61     Tuesday     6
# 62     Tuesday     6
# 63     Tuesday     6

# %%
len(bots)/len(df)
# Out:
# 0.03361521513737688
